# %%
import numpy as np
from sklearn.pipeline import Pipeline
from python.utils import load_data, get_features_from 
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import SimpleImputer
from sklearn.model_selection import GroupKFold
from python.features_extraction import ExtractFeatures
from sklearn.model_selection import cross_validate
from python.utils import write_submission
from sklearn.preprocessing import StandardScaler
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
import tensorflow as tf
from tensorflow import keras
from scikeras.wrappers import KerasClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression

# %%
fc_parameters = {
    "abs_energy": None,
    "maximum": None,
    "absolute_sum_of_changes": None,
    "fft_coefficient": [{"coeff": 10, "attr": "abs"}],
    "fourier_entropy": [{"bins": 10}],
    "linear_trend": [{"attr": "slope"}],
    "mean": None,
    "number_peaks": [{"n":4}],
    "variance": None,
}

# %%
def create_model(meta):
    n_features_in_ = meta["n_features_in_"]
    X_shape_ = meta["X_shape_"]
    n_classes_ = meta["n_classes_"]
    
    model = keras.models.Sequential()
    model.add(keras.layers.Dense(n_features_in_, input_shape=X_shape_[1:]))
    model.add(keras.layers.Dropout(rate=0.2))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.Dense(300, activation="relu"))
    model.add(keras.layers.Dropout(rate=0.2))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.Dense(100, activation="relu"))
    model.add(keras.layers.Dropout(rate=0.2))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.Dense(n_classes_, activation="softmax"))

    return model

# %%
DATA_PATH = 'data'
X_train, y_train, X_test, subjects = load_data(DATA_PATH)
# Out:
# X_train size: (3500, 15872).
# y_train size: (3500,).
# X_test size: (3500, 15872).

# %%
pre_process = Pipeline([
    ("si", SimpleImputer(missing_values=-999999.99, strategy="mean")),
    ("pp", ExtractFeatures(fc_parameters)),
    ("si2", SimpleImputer(missing_values=np.nan, strategy="mean")),
    ("ss", StandardScaler())
])

# %%
X_train_fe = get_features_from(folder="LS/not_scaled")
X_test_fe = get_features_from(folder="TS/not_scaled")

# %%
stacking_clf = Pipeline([
    ("pp", pre_process),
    ("vot", StackingClassifier(
        estimators=[("rnf_cls", RandomForestClassifier(random_state=42, n_estimators=500, max_features=4,max_depth=15,max_samples=0.4, bootstrap=True)),
                    ("svc", OneVsRestClassifier(estimator=SVC(C=0.25, kernel='poly', degree=3, coef0=2, gamma='scale', random_state=42, probability=True))),
                    ("knn", KNeighborsClassifier(n_neighbors=10,weights='distance', p=1)),
                    ("ada", AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=10, random_state=42), n_estimators=200, random_state=42)),
                    ("dnn", KerasClassifier(create_model,loss="sparse_categorical_crossentropy", epochs=100, verbose=0))
                    ],
        final_estimator=LogisticRegression(max_iter=2000)
    )) 
])

# %%
cv_res = cross_validate(stacking_clf, X_train, y_train-1, groups=subjects, cv=GroupKFold(len(np.unique(subjects))), return_train_score=True, scoring="accuracy")
cv_res["test_score"].mean()
# Out:
# Feature Extraction: 100%|██████████| 20/20 [00:02<00:00,  6.75it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:02<00:00,  7.05it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  6.36it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:02<00:00,  6.73it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:02<00:00,  7.62it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:02<00:00,  8.35it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:02<00:00,  8.07it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:02<00:00,  8.33it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:02<00:00,  7.80it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.17it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.99it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:02<00:00,  6.72it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  6.14it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  6.52it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:02<00:00,  6.74it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:02<00:00,  7.67it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:02<00:00,  6.69it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  6.07it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:02<00:00,  6.95it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:02<00:00,  7.20it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  6.58it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:02<00:00,  6.97it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  6.36it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:02<00:00,  7.76it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:02<00:00,  6.71it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:02<00:00,  7.25it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:02<00:00,  8.01it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:02<00:00,  7.50it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:02<00:00,  7.41it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:02<00:00,  9.02it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:02<00:00,  7.02it/s]
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f556456e560> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f556456e560> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f556653bcb0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f556653bcb0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f5588268f80> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f5588268f80> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f5566224f80> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f5566224f80> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f5566426dd0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f5566426dd0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f5566204cb0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f5566204cb0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f55665ad830> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f55665ad830> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f5566490d40> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f5566490d40> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f55a27bc440> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f55a27bc440> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f5565cf29e0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f5565cf29e0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f5643f0b7a0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f5643f0b7a0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 15.59it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 18.74it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 10.13it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 15.62it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 18.19it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 14.64it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 14.51it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 15.09it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 14.21it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 14.62it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 14.71it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 15.33it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 12.64it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 15.69it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 16.57it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 17.03it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 16.97it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 17.45it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 16.91it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 17.94it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 17.51it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 16.73it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 17.68it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 15.98it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 18.11it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 18.89it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 13.26it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 16.33it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 13.16it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 18.93it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 19.37it/s]
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f55885b3e60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f55885b3e60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Feature Extraction: 100%|██████████| 20/20 [00:02<00:00,  6.95it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:02<00:00,  7.16it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.29it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.67it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.99it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.36it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:04<00:00,  4.61it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  6.24it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.50it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.62it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.93it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.69it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:02<00:00,  6.73it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.49it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  6.13it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  6.17it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.93it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.47it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  6.08it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:04<00:00,  4.37it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.51it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.08it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:05<00:00,  3.86it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  6.59it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.39it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.28it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.70it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.77it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:04<00:00,  4.73it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  6.03it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:02<00:00,  7.11it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.27it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.81it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.20it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  6.28it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  6.58it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.22it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:02<00:00,  6.96it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.80it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  6.38it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.85it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.97it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:04<00:00,  4.86it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.52it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.35it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.49it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.64it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.27it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  6.24it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  6.44it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  6.08it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:02<00:00,  7.10it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:02<00:00,  6.77it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  6.43it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  6.60it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  6.42it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.40it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.11it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:04<00:00,  4.42it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.21it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  6.32it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.74it/s]
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f55887945f0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f55887945f0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f55667c4950> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f55667c4950> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f55a00bfb90> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f55a00bfb90> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f5566159e60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f5566159e60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f55882350e0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f55882350e0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f55a313ed40> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f55a313ed40> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f5566224dd0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f5566224dd0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f55a2c6ea70> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f55a2c6ea70> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f55a3117830> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f55a3117830> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f556456e0e0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f556456e0e0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f55664268c0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f55664268c0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 15.28it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 17.39it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 12.97it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 15.56it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 18.97it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 16.25it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 14.45it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 15.88it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 18.60it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 16.39it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 13.34it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 14.41it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 17.41it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 17.56it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 16.73it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 16.58it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 16.20it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 16.86it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 15.82it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 14.27it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 18.33it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 16.81it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 10.97it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 16.39it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 15.28it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 13.72it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 14.57it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 15.99it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 15.44it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 14.23it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 15.40it/s]
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f558841ddd0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f558841ddd0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.69it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.82it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.23it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  6.56it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.09it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.75it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  6.17it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.23it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  6.35it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  6.13it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:04<00:00,  4.99it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.80it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:02<00:00,  8.29it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  6.14it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  6.19it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:04<00:00,  4.34it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  6.03it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.08it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  6.49it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:04<00:00,  4.56it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.60it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.71it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.83it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.74it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:04<00:00,  4.96it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.35it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.90it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.37it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.95it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.67it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:04<00:00,  4.89it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.15it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.16it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.07it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:04<00:00,  4.50it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.28it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  6.07it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.95it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.46it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:04<00:00,  4.91it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.23it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:04<00:00,  4.96it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  6.20it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.25it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.04it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:04<00:00,  4.76it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:04<00:00,  4.46it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.47it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.01it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:04<00:00,  4.71it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  6.23it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.36it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.04it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.11it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.62it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  6.43it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:02<00:00,  6.94it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.41it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:04<00:00,  4.59it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:04<00:00,  4.29it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:02<00:00,  7.15it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.67it/s]
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f55661a2d40> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f55661a2d40> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert

# %%
stacking_clf.fit(X_train_fe, y_train-1)

# %%
y_pred = stacking_clf.predict(X_test_fe) + 1
write_submission(y_pred, 'submissions')
